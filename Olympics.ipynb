# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('olympics_dataset.csv', encoding= 'unicode_escape')

# %%
df.shape  #to get number of rows & col
# Out:
# (9836, 11)

# %%
df.head(10) # to get heading or tittle of each col
# Out:
#    player_id                   Name Sex            Team  NOC    Year  Season  \
# 0          0              A Dijiang   M           China  CHN  1992.0  Summer
# 1          1               A Lamusi   M           China  CHN  2012.0  Summer
# 2          2            Gunnar Aaby   M         Denmark  DEN  1920.0  Summer
# 3          3            Edgar Aabye   M  Denmark/Sweden  DEN  1900.0  Summer
# 4         26  Cornelia (-strannood)   F     Netherlands  NED  1932.0  Summer
# 5         27  Cornelia (-strannood)   F     Netherlands  NED  1932.0  Summer
# 6         29            Einar Aalto   M         Finland  FIN  1952.0  Summer
# 7         31             Jyri Aalto   M         Finland  FIN  2000.0  Summer
# 8         32            Minna Aalto   F         Finland  FIN  1996.0  Summer
# 9         33            Minna Aalto   F         Finland  FIN  2000.0  Summer
#
#           City       Sport                                   Event     Medal
# ...

# %%
df.info() # column wise full detail in general like null_values, data type.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9835 entries, 0 to 9834
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   player_id  9835 non-null   int64
#  1   Name       9835 non-null   object
#  2   Sex        9835 non-null   object
#  3   Team       9835 non-null   object
#  4   NOC        9835 non-null   object
#  5   Year       9835 non-null   int64
#  6   Season     9835 non-null   object
#  7   City       9835 non-null   object
#  8   Sport      9835 non-null   object
#  9   Event      9835 non-null   object
#  10  Medal      9835 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 922.0+ KB

# %%
df.describe()  # to get arithmetic values like mean, avg,  etc
# Out:
#           player_id         Year
# count   9836.000000  9835.000000
# mean    5674.834282  1979.151398
# std     3323.251060    29.550262
# min        0.000000  1896.000000
# 25%     2825.750000  1964.000000
# 50%     5566.500000  1988.000000
# 75%     8634.000000  2004.000000
# max    11509.000000  2016.000000

# %%
#check for null values in form of true-->null value is present & False-->actual value is present
pd.isnull(df)
# Out:
#       player_id   Name    Sex   Team    NOC   Year  Season   City  Sport  \
# 0         False  False  False  False  False  False   False  False  False
# 1         False  False  False  False  False  False   False  False  False
# 2         False  False  False  False  False  False   False  False  False
# 3         False  False  False  False  False  False   False  False  False
# 4         False  False  False  False  False  False   False  False  False
# ...         ...    ...    ...    ...    ...    ...     ...    ...    ...
# 9831      False  False  False  False  False  False   False  False  False
# 9832      False  False  False  False  False  False   False  False  False
# 9833      False  False  False  False  False  False   False  False  False
# 9834      False  False  False  False  False  False   False  False  False
# 9835      False   True   True   True   True   True    True   True   True
#
#       Event  Medal
# 0     False  False
# 1     False  False
# 2     False  False
# ...

# %%
# drop null values
df.dropna(inplace=True)

# %%
#check for null values
# df.isnull.sum() --> AttributeError: 'function' object has no attribute 'sum'

pd.isnull(df).sum()
# Out:
# player_id    0
# Name         0
# Sex          0
# Team         0
# NOC          0
# Year         0
# Season       0
# City         0
# Sport        0
# Event        0
# Medal        0
# dtype: int64

# %%
# change data type
df['Year'] = df['Year'].astype('int')

# %%
df.columns
# Out:
# Index(['player_id', 'Name', 'Sex', 'Team', 'NOC', 'Year', 'Season', 'City',
#        'Sport', 'Event', 'Medal'],
#       dtype='object')
